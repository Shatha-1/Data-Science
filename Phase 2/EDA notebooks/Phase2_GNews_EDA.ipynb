# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("gnews_articles_phase2_cleaned (1).csv")

df.head()
# Out:
#                                                  url  \
# 0  https://seekingalpha.com/news/4550005-moderna-...
# 1  https://www.foxnews.com/health/fda-refuses-rev...
# 2  https://www.cbsnews.com/news/moderna-says-fda-...
# 3  https://www.cnbctv18.com/lifestyle/healthcare/...
# 4  https://www.pennlive.com/health/2026/02/kenned...
#
#                  publishedAt  \
# 0  2026-02-11 07:54:39+00:00
# 1  2026-02-11 07:20:19+00:00
# 2  2026-02-11 04:28:28+00:00
# 3  2026-02-11 03:43:35+00:00
# 4  2026-02-11 02:55:05+00:00
#
#                                                title  \
# 0  Moderna shares drop after FDA refuses to file ...
# 1  FDA refuses to review Moderna’s mRNA flu vacci...
# 2  Moderna says FDA refuses its application for n...
# 3  Moderna says FDA refuses its application for n...
# 4  Moderna says FDA refuses its application for n...
#
#                                          description  \
# 0  Moderna’s mRNA-1010 flu vaccine application ge...
# 1  FDA refuses Moderna mRNA flu vaccine applicati...
# 2  The Food and Drug Administration is refusing t...
# 3  Moderna faces FDA refusal for its mRNA flu vac...
# 4  The decision follows a pattern of policy shift...
#
#                                              content  \
# 0  Moderna shares drop after FDA refuses to file ...
# 1  NEWYou can now listen to Fox News articles!\nT...
# 2  The Food and Drug Administration is refusing t...
# 3  FDA under Robert F. Kennedy Jr. refused to con...
# 4  By LAURAN NEERGAARD and MATTHEW PERRONE, The A...
#
#                    source_name                source_url  \
# 0                Seeking Alpha  https://seekingalpha.com
# 1                     Fox News   https://www.foxnews.com
# 2                     CBS News   https://www.cbsnews.com
# 3                    CNBC TV18  https://www.cnbctv18.com
# 4  Mechanicsburg Patriot News   https://www.pennlive.com
#
#                                            text_full  \
# 0  Moderna shares drop after FDA refuses to file ...
# 1  FDA refuses to review Moderna’s mRNA flu vacci...
# 2  Moderna says FDA refuses its application for n...
# 3  Moderna says FDA refuses its application for n...
# 4  Moderna says FDA refuses its application for n...
#
#                                           text_clean  \
# 0  Moderna shares drop after FDA refuses to file ...
# 1  FDA refuses to review Moderna’s mRNA flu vacci...
# 2  Moderna says FDA refuses its application for n...
# 3  Moderna says FDA refuses its application for n...
# 4  Moderna says FDA refuses its application for n...
#
#                                       text_processed
# 0  moderna share drop fda refuse file influenza v...
# 1  fda refuse review moderna mrna flu vaccine app...
# 2  moderna say fda refuse application new mrna fl...
# 3  moderna say fda refuse application new mrna fl...
# 4  moderna say fda refuse application new mrna fl...

# %%
df.shape
# Out:
# (110, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             110 non-null    object
#  1   publishedAt     110 non-null    object
#  2   title           110 non-null    object
#  3   description     110 non-null    object
#  4   content         110 non-null    object
#  5   source_name     110 non-null    object
#  6   source_url      110 non-null    object
#  7   text_full       110 non-null    object
#  8   text_clean      110 non-null    object
#  9   text_processed  110 non-null    object
# dtypes: object(10)
# memory usage: 8.7+ KB

# %%
df.isna().sum()
# Out:
# url               0
# publishedAt       0
# title             0
# description       0
# content           0
# source_name       0
# source_url        0
# text_full         0
# text_clean        0
# text_processed    0
# dtype: int64

# %%
df.describe()
# Out:
#                                                       url  \
# count                                                 110
# unique                                                110
# top     https://seekingalpha.com/news/4550005-moderna-...
# freq                                                    1
#
#                       publishedAt  \
# count                         110
# unique                        103
# top     2026-01-16 23:26:00+00:00
# freq                            3
#
#                                                     title  \
# count                                                 110
# unique                                                 92
# top     Moderna says FDA refuses its application for n...
# freq                                                   10
#
#                                               description  \
# count                                                 110
# unique                                                102
# top     Many people are still being urged to get vacci...
# freq                                                    5
#
#                                                   content   source_name  \
# count                                                 110           110
# unique                                                103            84
# top     Influenza cases are surging throughout the UK,...  Devdiscourse
# freq                                                    4             5
#
#                           source_url  \
# count                            110
# unique                            84
# top     https://www.devdiscourse.com
# freq                               5
#
#                                                 text_full  \
# count                                                 110
# unique                                                106
# top     Six groups of people urged to get flu vaccine ...
# freq                                                    4
#
#                                                text_clean  \
# count                                                 110
# unique                                                106
# top     Six groups of people urged to get flu vaccine ...
# freq                                                    4
#
#                                            text_processed
# count                                                 110
# unique                                                106
# top     six group people urge get flu vaccine severe s...
# freq                                                    4

# %%
df["source_name"].value_counts()
# Out:
# source_name
# Devdiscourse             5
# News-Medical.net         4
# Medical Xpress           4
# The Manila Times         3
# The Independent          3
#                         ..
# The London Free Press    1
# Dhaka Tribune            1
# The Conversation         1
# The Mirror               1
# Daily Express            1
# Name: count, Length: 84, dtype: int64

# %%
df['source_name'].value_counts().head(10).plot(kind="bar")

plt.title("Top News Sources")
plt.xlabel("Source")
plt.ylabel("Number of Articles")
plt.xticks(rotation=45)
plt.show()

# %%
df["article_length"] = df["text_full"].astype(str).apply(len)
df["article_length"].head()
# Out:
# 0    449
# 1    516
# 2    478
# 3    475
# 4    466
# Name: article_length, dtype: int64

# %%
plt.hist(df["article_length"], bins=30)

plt.title("Distribution of Article Length")
plt.xlabel("Article Length")
plt.ylabel("Frequency")

plt.show()

# %%
df["publishedAt"] = pd.to_datetime(df["publishedAt"])

# %%
articles_per_day = df.groupby(df["publishedAt"].dt.date).size()

articles_per_day.plot()

plt.title("Articles Published Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Articles")
articles_per_day.plot(kind="line", figsize=(8,5))
plt.xticks(rotation=45)

plt.show()

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from collections import Counter

words = " ".join(df["title"].astype(str)).lower().split()

custom_stopwords = {"says", "said", "new"}

filtered_words = [
    word for word in words
    if word not in ENGLISH_STOP_WORDS
    and word not in custom_stopwords
    and len(word) > 2
]

common_words = Counter(filtered_words).most_common(10)

# %%
words_df = pd.DataFrame(common_words, columns=["word", "count"])

words_df.plot(kind="bar", x="word", y="count")

plt.title("Most Common Words in News Titles (Without Stopwords)")
plt.xlabel("Word")
plt.ylabel("Frequency")

plt.show()
